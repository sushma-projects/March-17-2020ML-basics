# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Visualization
# - Bivariate
# - Univariate

# %% [markdown]
# Functions
# - plot
# - scatter
# - bar
# - pie
# - hitogram
# - fill_between
# - step

# %%
x = np.random.randint(50,200,20)
y = np.random.randint(50,200,20)
plt.scatter(x,y)

# %%
x = np.random.randint(50,200,20)
y = np.random.randint(50,200,20)
plt.plot(x,y,marker='o')

# %%
x = np.array([10,20,30,40,50])
y = np.array([12,22,32,42,100])
plt.scatter(x,y)

# %%
help(plt.scatter)
# Out:
# Help on function scatter in module matplotlib.pyplot:
#
# scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None, **kwargs)
#     A scatter plot of *y* vs *x* with varying marker size and/or color.
#
#     Parameters
#     ----------
#     x, y : array_like, shape (n, )
#         The data positions.
#
#     s : scalar or array_like, shape (n, ), optional
#         The marker size in points**2.
#         Default is ``rcParams['lines.markersize'] ** 2``.
#
#     c : color, sequence, or sequence of color, optional, default: 'b'
#         The marker color. Possible values:
#
#         - A single color format string.
#         - A sequence of color specifications of length n.
#         - A sequence of n numbers to be mapped to colors using *cmap* and
#           *norm*.
#         - A 2-D array in which the rows are RGB or RGBA.
#
# ...

# %%
plt.scatter(x,y,marker='*')

# %%
plt.scatter(x,y,marker='*',c='r')
plt.scatter(x,x*x,c='b')

# %%
branches = pd.Series(["ECE","IT","CSE","IT","CSE","ECE","IT"])
branches
# Out:
# 0    ECE
# 1     IT
# 2    CSE
# 3     IT
# 4    CSE
# 5    ECE
# 6     IT
# dtype: object

# %%
branches.nunique()
# Out:
# 3

# %%
branches.unique()
# Out:
# array(['ECE', 'IT', 'CSE'], dtype=object)

# %%
branches.value_counts()
# Out:
# IT     3
# ECE    2
# CSE    2
# dtype: int64

# %%
branch_wise =branches.value_counts()
branch_wise
# Out:
# IT     3
# ECE    2
# CSE    2
# dtype: int64

# %%
unique_branch = branch_wise.index
unique_branch
# Out:
# Index(['IT', 'ECE', 'CSE'], dtype='object')

# %%
plt.bar(unique_branch,branch_wise)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(["hotels","hospitals"],[10,15])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(["hotels","hospitals"],[10,15],color="rg")
# Out:
# <BarContainer object of 2 artists>

# %%
branches.value_counts(normalize=True)
# Out:
# IT     0.428571
# ECE    0.285714
# CSE    0.285714
# dtype: float64

# %%
branches.shape[0]
# Out:
# 7

# %%
branches.value_counts()/branches.shape[0]
# Out:
# IT     0.428571
# ECE    0.285714
# CSE    0.285714
# dtype: float64

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, hold=None, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : array-like
#         The wedge sizes.
#
#     explode : array-like, optional, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
# ...

# %%
plt.pie(branches.value_counts(normalize=True),labels=branch_wise.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x2029529fd68>,
# ...
#  [Text(0.244773,1.07242,'IT'),
#   Text(-0.991066,-0.477272,'ECE'),
#   Text(0.685839,-0.860015,'CSE')])

# %%
plt.pie(branches.value_counts(normalize=True),labels=branch_wise.index,colors = ["r","g","y"])
# Out:
# ([<matplotlib.patches.Wedge at 0x20295263cc0>,
# ...
#  [Text(0.244773,1.07242,'IT'),
#   Text(-0.991066,-0.477272,'ECE'),
#   Text(0.685839,-0.860015,'CSE')])

# %%
plt.pie(branches.value_counts(normalize=True),[0,0.1,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x202952e7198>,
# ...
#  [Text(0.244773,1.07242,''),
#   Text(-1.08116,-0.520661,''),
#   Text(0.685839,-0.860015,'')])

# %%
x = np.random.randint(1,25,100)
x
# Out:
# array([21, 13, 18, 13, 24, 19,  1,  5, 11, 10, 11, 10,  2,  8, 18,  8, 14,
#        19, 13,  7,  5, 22, 23,  7,  5,  1,  1, 16, 15, 24, 19, 16,  1, 23,
#        24, 20, 13, 22, 10, 18,  3,  3, 21, 19, 23, 13, 17, 16, 16, 11,  8,
#        15,  7,  6, 22,  6,  6,  6, 23, 20,  7, 23,  4, 16, 20, 16, 17,  1,
#        23, 13, 18, 16, 22,  3,  2, 19, 13, 15, 11,  3, 21, 12,  2,  2,  1,
#        16, 16, 16,  8, 14,  3, 10, 12, 24,  7, 15,  1, 19,  3,  1])

# %% [markdown]
# - frequency
# - binsize or width
# - bin

# %%
plt.hist(x)
# Out:
# (array([18.,  4.,  9.,  8.,  6.,  9., 16., 10.,  6., 14.]),
#  array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ]),
#  <a list of 10 Patch objects>)

# %%
np.linspace(np.min(x),np.max(x),11)
# Out:
# array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ])

# %%
((x>=1)&(x<3.3)).sum()
# Out:
# 18

# %%
plt.hist(x,bins=5)
# Out:
# (array([22., 17., 15., 26., 20.]),
#  array([ 1. ,  5.6, 10.2, 14.8, 19.4, 24. ]),
#  <a list of 5 Patch objects>)

# %%
((x>=1)&(x<5.6)).sum()
# Out:
# 22

# %%
((x>=5.6)&(x<10.2)).sum()
# Out:
# 17

# %%
x = np.array([1,2,3,1,1,1,1,2,1,1,10,20,30,45])
plt.hist(x,bins=5)
# Out:
# (array([10.,  1.,  1.,  1.,  1.]),
#  array([ 1. ,  9.8, 18.6, 27.4, 36.2, 45. ]),
#  <a list of 5 Patch objects>)

# %%
#Task
#positively skewed data
#negatively skewed data
#How to identify whether it is a positively skewed or negatively skewed data from histogram

# %%
x = np.array([1,1,1,5,5,5,10,10,10,10])
plt.hist(x,bins=3)
# Out:
# (array([3., 3., 4.]), array([ 1.,  4.,  7., 10.]), <a list of 3 Patch objects>)

# %%
x = np.random.randint(1,25,100)
plt.hist(x)
# Out:
# (array([ 8.,  7., 12., 11.,  8.,  7., 15.,  8., 12., 12.]),
#  array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x,cumulative=True)
# Out:
# (array([  8.,  15.,  27.,  38.,  46.,  53.,  68.,  76.,  88., 100.]),
#  array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# - cumulative=False
#     - (array([ 8.,  7., 12., 11.,  8.,  7., 15.,  8., 12., 12.]),
#        array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ])
# - cumulative=True
#     - (array([  8.,  15.,  27.,  38.,  46.,  53.,  68.,  76.,  88., 100.]),
#       array([ 1. ,  3.3,  5.6,  7.9, 10.2, 12.5, 14.8, 17.1, 19.4, 21.7, 24. ])

# %%
x = np.array([20,30,10,40,50])
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20295715208>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20295715ba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x202957150b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2029571d4a8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2029571d908>],
#  'means': []}

# %%
q1 = (x,(0.25))
q2 = (x,(0.50))
q3 = (x,(0.75))

# %%
print(q1,q2,q3)
# Out:
# (array([20, 30, 10, 40, 50]), 0.25) (array([20, 30, 10, 40, 50]), 0.5) (array([20, 30, 10, 40, 50]), 0.75)

# %% [markdown]
# IQR = (q3-q1)
# -

# %%
x = np.array([1,2,3,4,1,4])
y = np.array([2,3,4,5,6,1])
plt.fill_between(x,y)

# %%
plt.fill_between(np.arange(5),x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3c7b59fe9e43> in <module>()
# ----> 1 plt.fill_between(np.arange(5),x,y)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in fill_between(x, y1, y2, where, interpolate, step, hold, data, **kwargs)
#    3052         ret = ax.fill_between(x, y1, y2=y2, where=where,
#    3053                               interpolate=interpolate, step=step, data=data,
# -> 3054                               **kwargs)
#    3055     finally:
#    3056         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
plt.step([1,2,3,4],[5,5,7,6])

# %%
plt.subplot(1,2,1)
plt.pie(branches.value_counts())
plt.subplot(1,2,2)
plt.bar(branches.value_counts().index,branches.value_counts())
# Out:
# <BarContainer object of 3 artists>
